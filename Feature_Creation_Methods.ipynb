# %% [markdown]
# # Feature Creation Methods
# Call these methods to add features to the Flights Training dataframe

# %%
from datetime import datetime

# %% [markdown]
# ## 1. Is Flight Delayed Feature (0 or 1 values)

# %%
def is_delayed_feature(flights_df):
    flights_df_cp = flights_df.copy()
    
    flights_df_cp['dep_delay'] = flights_df_cp['dep_delay'].fillna(0)
    flights_df_cp['arr_delay'] = flights_df_cp['arr_delay'].fillna(0)
    flights_df_cp['carrier_delay'] = flights_df_cp['carrier_delay'].fillna(0)
    flights_df_cp['weather_delay'] = flights_df_cp['weather_delay'].fillna(0)
    flights_df_cp['nas_delay'] = flights_df_cp['nas_delay'].fillna(0)
    flights_df_cp['security_delay'] = flights_df_cp['security_delay'].fillna(0)
    flights_df_cp['late_aircraft_delay'] = flights_df_cp['late_aircraft_delay'].fillna(0)

    flights_df_cp['total_delay'] = flights_df_cp.apply(
        lambda x: ((x['dep_delay'] + x['arr_delay'] +
                 x['carrier_delay'] +
                 x['weather_delay'] + x['nas_delay'] + x['security_delay'] +
                 x['late_aircraft_delay']
        )),  axis=1)
    
    return flights_df_cp.apply(
        lambda x: (0 if x['total_delay'] <= 0 else 1),  axis=1)

# %% [markdown]
# ## 2. Flight Speed

# %%
def flight_speed_feature(flights_df):
    flights_df_cp = flights_df.copy()

   
    flights_df_cp['distance'] = flights_df_cp.apply(
        lambda x: (0.0 if ((x['cancelled'] == 1) | (x['diverted'] == 1)) else x['distance']
              ),  axis=1)
    
    flights_df_cp['actual_elapsed_time'] = flights_df_cp.apply(
        lambda x: (60.0 if ((x['cancelled'] == 1) | (x['diverted'] == 1)) else x['actual_elapsed_time']
              ),  axis=1)
    
    return flights_df_cp.apply(
        lambda x: ((x['distance'] / (x['actual_elapsed_time']/60)
              )),  axis=1)

# %% [markdown]
# ## 3. Flight Haul Type (values of 0, 1 and 2 for Short, Medium and Long)

# %%
def flight_haul_type_feature(flights_df):
    flights_df_cp = flights_df.copy()
    
    flights_df_cp['actual_elapsed_time'] = flights_df_cp.apply(
        lambda x: (0 if ((x['cancelled'] == 1) | (x['diverted'] == 1)) else x['actual_elapsed_time']
              ),  axis=1)
    
    return flights_df_cp.apply(
        lambda x: 0 if x['actual_elapsed_time'] <= 180.0 else (2 if x['actual_elapsed_time'] >= 360.0 else 1), axis=1
)

# %% [markdown]
# ## 4. Month of the Year (1 to 12)

# %%
def month_feature(flights_df):
    flights_df_cp = flights_df.copy()
    
    return flights_df_cp[flights_df_cp['fl_date'].notna()].apply(
        lambda x: datetime.strptime(x['fl_date'], '%Y-%m-%d').date().month, axis=1)

# %% [markdown]
# ## 5. Arrival Hour of the Day (0 to 23)

# %%
def arrival_hour_of_day_feature(flights_df):
    flights_df_cp = flights_df.copy()
    
    return flights_df_cp[flights_df_cp['arr_time'].notna()].apply(
        lambda x: 0 if x['arr_time'] == 2400.0 else datetime.strptime(str(int(x['arr_time'])).zfill(4), '%H%M').time().hour, axis=1)

# %% [markdown]
# ## 6. Departure Hour of the Day (0 to 23)

# %%
def departure_hour_of_day_feature(flights_df):
    flights_df_cp = flights_df.copy()
    
    return flights_df_cp[flights_df_cp['dep_time'].notna()].apply(
        lambda x: 0 if x['dep_time'] == 2400.0 else datetime.strptime(str(int(x['dep_time'])).zfill(4), '%H%M').time().hour, axis=1)

# %% [markdown]
# sample data of top delayed location, early location

# %% [markdown]
# # Test All Methods

# %%
import pickle

filename = 'flight_2019'

infile = open(filename,'rb')
flight_2019 = pickle.load(infile)
infile.close()

# %% [markdown]
# #### New dataframe with a smaller sample of 500,000 records

# %%
flight_sample = flight_2019.sample(n=1000000, random_state=1)

# %%
flight_sample.shape
# Out:
# (1000000, 38)

# %%
flight_sample['fl_date'].head()
# Out:
# 5817519    2019-05-23
# 3440584    2019-12-05
# 2213756    2019-02-06
# 4372882    2019-09-17
# 2224046    2019-02-06
# Name: fl_date, dtype: object

# %%
flight_sample['is_delayed'] = is_delayed_feature(flight_sample)
flight_sample.head()
# Out:
#         mkt_unique_carrier branded_code_share  mkt_carrier_fl_num  \
# 5817519                 DL       DL_CODESHARE                4016
# 3440584                 DL       DL_CODESHARE                4566
# 2213756                 DL                 DL                2151
# 4372882                 AA                 AA                 439
# 2224046                 NK                 NK                 318
#
#         op_unique_carrier tail_num  op_carrier_fl_num  origin_airport_id  \
# 5817519                OO   N291SY               4016              12953
# 3440584                OO   N477CA               4566              10397
# 2213756                DL   N844DN               2151              10721
# 4372882                AA   N155NN                439              13930
# 2224046                NK   N907NK                318              14635
#
#          dest_airport_id  crs_dep_time  dep_time  ...  nas_delay  \
# 5817519            13342          1747    1944.0  ...        3.0
# 3440584            12007          2019    2017.0  ...        NaN
# 2213756            13487          1820    1802.0  ...        NaN
# 4372882            14107           705     656.0  ...        NaN
# 2224046            13487          1315    1311.0  ...        NaN
#
#          security_delay  late_aircraft_delay  first_dep_time  total_add_gtime  \
# 5817519             0.0                108.0            None              NaN
# 3440584             NaN                  NaN            None              NaN
# 2213756             NaN                  NaN            None              NaN
# 4372882             NaN                  NaN            None              NaN
# 2224046             NaN                  NaN            None              NaN
#
#          longest_add_gtime     fl_date    year  month is_delayed
# 5817519                NaN  2019-05-23  2019.0    5.0          1
# 3440584                NaN  2019-12-05  2019.0   12.0          0
# 2213756                NaN  2019-02-06  2019.0    2.0          0
# 4372882                NaN  2019-09-17  2019.0    9.0          0
# 2224046                NaN  2019-02-06  2019.0    2.0          0
#
# [5 rows x 39 columns]

# %%
flight_sample['flight_speed'] = flight_speed_feature(flight_sample)
flight_sample.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-97100992fcc4> in <module>
# ----> 1 flight_sample['flight_speed'] = flight_speed_feature(flight_sample)
#       2 flight_sample.head()
#
# <ipython-input-4-52f1c5281261> in flight_speed_feature(flights_df)
#       6     )]
#       7
# ----> 8     flights_df_cp['distance'] = flights_df_cp.apply(
#       9         lambda x: (0 if (x['cancelled'] == 1 | x['diverted'] == 1) else x['distance']
#      10               ),  axis=1)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     293
#     294             try:
# --> 295                 result = libreduction.compute_reduction(
#     296                     values, self.f, axis=self.axis, dummy=dummy, labels=labels
#     297                 )
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.compute_reduction()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# <ipython-input-4-52f1c5281261> in <lambda>(x)
#       7
#       8     flights_df_cp['distance'] = flights_df_cp.apply(
# ----> 9         lambda x: (0 if (x['cancelled'] == 1 | x['diverted'] == 1) else x['distance']
#      10               ),  axis=1)
#      11
#
# TypeError: unsupported operand type(s) for |: 'int' and 'float'

# %%
flight_sample['flight_haul_type'] = flight_haul_type_feature(flight_sample)
flight_sample.head()
# Out:
#         mkt_unique_carrier branded_code_share  mkt_carrier_fl_num  \
# 5817519                 DL       DL_CODESHARE                4016
# 3440584                 DL       DL_CODESHARE                4566
# 2213756                 DL                 DL                2151
# 4372882                 AA                 AA                 439
# 2224046                 NK                 NK                 318
#
#         op_unique_carrier tail_num  op_carrier_fl_num  origin_airport_id  \
# 5817519                OO   N291SY               4016              12953
# 3440584                OO   N477CA               4566              10397
# 2213756                DL   N844DN               2151              10721
# 4372882                AA   N155NN                439              13930
# 2224046                NK   N907NK                318              14635
#
#          dest_airport_id  crs_dep_time  dep_time  ...  late_aircraft_delay  \
# 5817519            13342          1747    1944.0  ...                108.0
# 3440584            12007          2019    2017.0  ...                  NaN
# 2213756            13487          1820    1802.0  ...                  NaN
# 4372882            14107           705     656.0  ...                  NaN
# 2224046            13487          1315    1311.0  ...                  NaN
#
#          first_dep_time  total_add_gtime  longest_add_gtime     fl_date  \
# 5817519            None              NaN                NaN  2019-05-23
# 3440584            None              NaN                NaN  2019-12-05
# 2213756            None              NaN                NaN  2019-02-06
# 4372882            None              NaN                NaN  2019-09-17
# 2224046            None              NaN                NaN  2019-02-06
#
#            year  month  is_delayed  flight_speed flight_haul_type
# 5817519  2019.0    5.0           1    297.181208                0
# 3440584  2019.0   12.0           0    229.523810                0
# 2213756  2019.0    2.0           0    328.975610                1
# 4372882  2019.0    9.0           0    374.025974                1
# 2224046  2019.0    2.0           0    382.702703                1
#
# [5 rows x 41 columns]

# %%
flight_sample['flight_month'] = month_feature(flight_sample)
flight_sample.head()
# Out:
#         mkt_unique_carrier branded_code_share  mkt_carrier_fl_num  \
# 5817519                 DL       DL_CODESHARE                4016
# 3440584                 DL       DL_CODESHARE                4566
# 2213756                 DL                 DL                2151
# 4372882                 AA                 AA                 439
# 2224046                 NK                 NK                 318
#
#         op_unique_carrier tail_num  op_carrier_fl_num  origin_airport_id  \
# 5817519                OO   N291SY               4016              12953
# 3440584                OO   N477CA               4566              10397
# 2213756                DL   N844DN               2151              10721
# 4372882                AA   N155NN                439              13930
# 2224046                NK   N907NK                318              14635
#
#          dest_airport_id  crs_dep_time  dep_time  ...  first_dep_time  \
# 5817519            13342          1747    1944.0  ...            None
# 3440584            12007          2019    2017.0  ...            None
# 2213756            13487          1820    1802.0  ...            None
# 4372882            14107           705     656.0  ...            None
# 2224046            13487          1315    1311.0  ...            None
#
#          total_add_gtime  longest_add_gtime     fl_date    year  month  \
# 5817519              NaN                NaN  2019-05-23  2019.0    5.0
# 3440584              NaN                NaN  2019-12-05  2019.0   12.0
# 2213756              NaN                NaN  2019-02-06  2019.0    2.0
# 4372882              NaN                NaN  2019-09-17  2019.0    9.0
# 2224046              NaN                NaN  2019-02-06  2019.0    2.0
#
#          is_delayed  flight_speed  flight_haul_type flight_month
# 5817519           1    297.181208                 0            5
# 3440584           0    229.523810                 0           12
# 2213756           0    328.975610                 1            2
# 4372882           0    374.025974                 1            9
# 2224046           0    382.702703                 1            2
#
# [5 rows x 42 columns]

# %%
flight_sample['arrival_hour_of_day'] = arrival_hour_of_day_feature(flight_sample)
flight_sample.head()
# Out:
#         mkt_unique_carrier branded_code_share  mkt_carrier_fl_num  \
# 5817519                 DL       DL_CODESHARE                4016
# 3440584                 DL       DL_CODESHARE                4566
# 2213756                 DL                 DL                2151
# 4372882                 AA                 AA                 439
# 2224046                 NK                 NK                 318
#
#         op_unique_carrier tail_num  op_carrier_fl_num  origin_airport_id  \
# 5817519                OO   N291SY               4016              12953
# 3440584                OO   N477CA               4566              10397
# 2213756                DL   N844DN               2151              10721
# 4372882                AA   N155NN                439              13930
# 2224046                NK   N907NK                318              14635
#
#          dest_airport_id  crs_dep_time  dep_time  ...  total_add_gtime  \
# 5817519            13342          1747    1944.0  ...              NaN
# 3440584            12007          2019    2017.0  ...              NaN
# 2213756            13487          1820    1802.0  ...              NaN
# 4372882            14107           705     656.0  ...              NaN
# 2224046            13487          1315    1311.0  ...              NaN
#
#          longest_add_gtime     fl_date    year  month  is_delayed  \
# 5817519                NaN  2019-05-23  2019.0    5.0           1
# 3440584                NaN  2019-12-05  2019.0   12.0           0
# 2213756                NaN  2019-02-06  2019.0    2.0           0
# 4372882                NaN  2019-09-17  2019.0    9.0           0
# 2224046                NaN  2019-02-06  2019.0    2.0           0
#
#          flight_speed  flight_haul_type  flight_month arrival_hour_of_day
# 5817519    297.181208                 0             5                21.0
# 3440584    229.523810                 0            12                20.0
# 2213756    328.975610                 1             2                20.0
# 4372882    374.025974                 1             9                 8.0
# 2224046    382.702703                 1             2                15.0
#
# [5 rows x 43 columns]

# %%
flight_sample['departure_hour_of_day'] = departure_hour_of_day_feature(flight_sample)
flight_sample.head()
